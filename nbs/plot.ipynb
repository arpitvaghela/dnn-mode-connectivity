# %%
import numpy as np

# %%
x = np.load("./curves/eval/curve.npz")

# %%
x["ts"].shape
# Out:
# (61,)

# %%
for i in x:
    print(i)
# Out:
# ts
# dl
# tr_loss
# tr_loss_min
# tr_loss_max
# tr_loss_avg
# tr_loss_int
# tr_nll
# tr_nll_min
# tr_nll_max
# tr_nll_avg
# tr_nll_int
# tr_acc
# tr_err
# tr_err_min
# tr_err_max
# tr_err_avg
# tr_err_int
# te_loss
# te_loss_min
# te_loss_max
# te_loss_avg
# te_loss_int
# te_nll
# te_nll_min
# te_nll_max
# te_nll_avg
# te_nll_int
# te_acc
# te_err
# te_err_min
# te_err_max
# te_err_avg
# te_err_int

# %%
x["te_loss"].shape,x["dl"].shape

import matplotlib.pyplot as plt
ax = plt.plot(x["ts"], x["te_loss"])
plt.show()

# %%
ax = plt.plot(x["ts"], x["tr_err"])
plt.show()

# %%
pn = np.load("./curves/eval/plane.npz")

# %%
for i in pn:
    print(i, pn[i].shape)
# Out:
# ts (61,)
# bend_coordinates (3, 2)
# curve_coordinates (61, 2)
# alphas (21,)
# betas (21,)
# grid (21, 21, 2)
# tr_loss (21, 21)
# tr_acc (21, 21)
# tr_nll (21, 21)
# tr_err (21, 21)
# te_loss (21, 21)
# te_acc (21, 21)
# te_nll (21, 21)
# te_err (21, 21)

# %%
plt.contourf(pn["te_acc"], levels=50, cmap="Blues")
